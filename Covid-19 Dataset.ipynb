# %% [markdown]
# # Covid-19 Data Analysis

# %%
#Import all Required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('covid.csv')

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.shape
# Out:
# (321, 6)

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()
#white column show null values

# %% [markdown]
# # Q1) show the number of Confirmed,Recovered,Death in Regions

# %%
#df.groupby('Region').sum().head(50)
#df.groupby('Region')['Confirmed'].sum().sum values(ascending =false).head(50)
#df.groupby('Region')['Confirmed','Recovered'].sum()

# %%
data.groupby('Region')

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
# only show Confirmed
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# <ipython-input-12-20fd7b835859>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# # Q2) Remove all Records where Confirmed Cases  is Less then 10

# %%
#df.Confirmed < 10
#df[df.Confirmed < 10]
#df[~(df.Confirmed < 10)]
#df = df[~(df.Confirmed < 10)]

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.Confirmed < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[data.Confirmed < 10]
#this will show u the confiremed cases less than 10
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
# To remove all Confirm cases less than 10 ,we will use ~

# %%
data[~(data.Confirmed < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data = data[~(data.Confirmed < 10)]

# %%
# All Confirm cases less than 10 is Remove

# %%
data.shape
# Out:
# (304, 6)

# %% [markdown]
# # Q3) In which Region ,Maximum number of Confirmed Cases were Recorded ?

# %%
#df.groupby('Region').Confirmed.sum().sort_values(ascending = False).head()

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head()
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166536
# UK         166432
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q4)In which Region ,Minimum number of Deaths Cases were Recorded ?¶

# %%
#df.groupby('Region').Deaths.sum().sort_values(ascending = True).head()

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(25)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# # Q5) How many Confirmed, Deaths & Recovered cases were required from 29 April 2020

# %%
#df[df.Region == 'Country_name']

# %%
data[data.Region == 'India'].head()
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'US'].head()
# Out:
#           Date       State Region  Confirmed  Deaths  Recovered
# 181  4/29/2020     Alabama     US       6912     256          0
# 182  4/29/2020      Alaska     US        355       9          0
# 186  4/29/2020     Arizona     US       7209     308          0
# 187  4/29/2020    Arkansas     US       3193      57          0
# 195  4/29/2020  California     US      48747    1946          0

# %% [markdown]
# # Q6) Sort the Entire data wrt No. of Confirmed cases in ascending order

# %%
#df.sort_values(by=['Confirmed'],ascending = True)

# %%
data.sort_values(by=['Confirmed'],ascending = True).head(20)
# Out:
#           Date                        State                            Region  \
# 156  4/29/2020                          NaN                          Suriname
# 70   4/29/2020                          NaN                          Holy See
# 59   4/29/2020                          NaN                            Gambia
# 318  4/29/2020                        Yukon                            Canada
# 217  4/29/2020                    Greenland                           Denmark
# 256  4/29/2020                   Montserrat                                UK
# 144  4/29/2020                          NaN                        Seychelles
# 27   4/29/2020                          NaN                           Burundi
# 306  4/29/2020     Turks and Caicos Islands                                UK
# 118  4/29/2020                          NaN                         Nicaragua
# 215  4/29/2020               Grand Princess                            Canada
# ...

# %%
#Q6-B)Sort the Entire data wrt No. of Confirmed cases in Descending order¶

# %%
#df.sort_values(by=['Confirmed'],ascending = True)

# %%
data.sort_values(by=['Confirmed'],ascending = False).head(20)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 265  4/29/2020       New York              US     299691   23477          0
# 153  4/29/2020            NaN           Spain     236899   24275     132929
# 80   4/29/2020            NaN           Italy     203591   27682      71252
# 168  4/29/2020            NaN              UK     165221   26097          0
# 57   4/29/2020            NaN          France     165093   24087      48228
# 61   4/29/2020            NaN         Germany     161539    6467     120400
# 167  4/29/2020            NaN          Turkey     117589    3081      44040
# 262  4/29/2020     New Jersey              US     116365    6771          0
# 134  4/29/2020            NaN          Russia      99399     972      10286
# 76   4/29/2020            NaN            Iran      93657    5957      73791
# 22   4/29/2020            NaN          Brazil      79685    5513      34132
# ...
